# %%
import requests
import pandas as pd

# %%
headers = {
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
'accept':'application/json',
'authorization': '6f64d6a047fad369d35c3806f8f8e0560475075a432585973f91caae35b4ad74'
} 

params = {
    'per_page': 1,
    'start_date': '',
    'end_date': '',
    'sort': '1'
}

id = '820' #Declaração do ID
url = 'https://app.inguru.me/api/v1/taxonomies/nodes/'+str(f'{id}')

response = requests.get(url, headers=headers, params=params)
print(response.json())
# Out:
# {'data': [{'id': 7867, 'created_at': '2021-03-26 09:12:29', 'updated_at': '2023-05-11 14:40:42', 'name': 'Investimento', 'expression': '(investimento OR investir* AND ("nova planta" OR "nova fábrica" OR "novo empreendimento" OR "nova unidade" OR "nova indústria")) NOT (bitcoin* OR "bolsa de valores")', 'initial_date': None, 'final_date': None, 'color': '#80B62E', 'children': [], 'links': {'news': 'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867'}}]}

# %%
number = 1
append_frame = pd.DataFrame()
while True:
    if response.json() is not None:

        headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
        'accept':'application/json',
        'authorization': '6f64d6a047fad369d35c3806f8f8e0560475075a432585973f91caae35b4ad74'
        } 

        params = {
            'per_page': 1000,
            'start_date': '',
            'end_date': '',
            'sort': '1'
        }

        # Quando maior 'per_page' maior 'informations' menor total_pages

        #'pagination': {'total': 4555,
        #'count': 2000,
        #'per_page': 2000,
        #'current_page': 1,
        #'total_pages': 2,
        #'links': {'next_page': 'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867?page=2',
        #'previous_page': None}}}

        #id = '820' #Declaração do ID
        url = f'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867?page={number}'

        response = requests.get(url, headers=headers, params=params)
        df = pd.json_normalize(response.json()['data'])
        append_frame = append_frame.append(df,ignore_index=True)

        print(response.json()['pagination']['total_pages'])
    number += 1
    if number > response.json()['pagination']['total_pages']:
        break

append_frame        
#display(append_frame)
# Out:
# C:\Users\zhang.yuan\AppData\Local\Temp\ipykernel_5164\968249305.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_frame = append_frame.append(df,ignore_index=True)
# 4
# C:\Users\zhang.yuan\AppData\Local\Temp\ipykernel_5164\968249305.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_frame = append_frame.append(df,ignore_index=True)
# 4
# C:\Users\zhang.yuan\AppData\Local\Temp\ipykernel_5164\968249305.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_frame = append_frame.append(df,ignore_index=True)
# 4
# 4
# C:\Users\zhang.yuan\AppData\Local\Temp\ipykernel_5164\968249305.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_frame = append_frame.append(df,ignore_index=True)
#              id                     domain  \
# 0       3941580    files.digital.em.com.br
# 1       3947636              www.em.com.br
# 2       4973042           www.valor.com.br
# 3       4955988           www.valor.com.br
# 4       4989376   images2.pressdisplay.com
# ...         ...                        ...
# 3995  180717724      acessepolitica.com.br
# 3996  180728144  www.diarioinduscom.com.br
# 3997  180732156         comvcportal.com.br
# 3998  180728491   www.correiodolago.com.br
# 3999  180737295   folhadecampolargo.com.br
#
#                                                   title  \
# 0                                           Mercado s/a
# 1                                           Mercado s/a
# 2     WestRock eleva a R$ 1,7 bilhão investimentos n...
# 3     WestRock eleva a R$ 1,7 bilhão investimentos n...
# 4     Ame­ri­ca­na WestRock vai in­ves­tir mais R$ 1...
# ...                                                 ...
# 3995  Venda de motos elétricas cresce mais de 340% e...
# 3996  Estado e chinesa BYD discutem instalação de um...
# 3997  Estado e chinesa BYD discutem instalação de um...
# 3998  Estado e chinesa BYD discutem instalação de um...
# 3999  Estado e chinesa BYD discutem instalação de um...
#
#                      subtitle         author  \
# 0                                       None
# 1     Estado de Minas Digital           None
# 2                              Stella Fontes
# 3                              Stella Fontes
# 4                                       None
# ...                       ...            ...
# 3995                                    None
# 3996                                    None
# 3997                                    None
# 3998                                    None
# 3999                                    None
#
#                                                 content  \
# 0     WhatsApp domina eleição, mas não dá dinheiro\n...
# 1     WhatsApp domina eleição, mas não dá dinheiro\n...
# 2     SÃO PAULO - Segunda maior fabricante do mundo ...
# 3     SÃO PAULO - Segunda maior fabricante do mundo ...
# 4     Segunda maior fabricante do mundo de embalagen...
# ...                                                 ...
# 3995  Home / NEGÓCIOS / Venda de motos elétricas cre...
# 3996  Foto: Camila Tonett/GVG\nFoto: Camila Tonett/G...
# 3997  Paraná Indústria\nEstado e chinesa BYD discute...
# 3998  A instalação de uma futura unidade da multinac...
# 3999  A instalação de uma futura unidade da multinac...
#
#                                                     url  \
# 0     http://s3.amazonaws.com/static.resources/origi...
# 1     https://www.em.com.br/app/noticia/assinante/ec...
# 2     https://www.valor.com.br/empresas/5969229/west...
# 3     https://www.valor.com.br/empresas/5969229/west...
# 4     http://s3.amazonaws.com/static.resources/origi...
# ...                                                 ...
# 3995  https://acessepolitica.com.br/venda-de-motos-e...
# 3996  https://www.diarioinduscom.com.br/Noticias/809...
# 3997  https://comvcportal.com.br/noticia/49305/estad...
# 3998  http://www.correiodolago.com.br/noticia/estado...
# 3999  https://folhadecampolargo.com.br/noticia/49711...
#
#                                  source source_country    source_state  \
# 0     Estado de Minas - Impresso - Flip             br    Minas Gerais
# 1              Estado de Minas - Online             br    Minas Gerais
# 2            Valor Econômico - Impresso             br       São Paulo
# 3                       Valor Econômico             br       São Paulo
# 4     Valor Econômico - Impresso - Flip             br       São Paulo
# ...                                 ...            ...             ...
# 3995                    Acesse Política             br           Bahia
# 3996        Diário Indústria & Comércio             br          Paraná
# 3997                              ComVc             br          Paraná
# 3998             Portal Correio do Lago             br  Santa Catarina
# 3999               Folha de Campo Largo             br          Paraná
#
#              crawled_date       published_date
# 0     2018-10-08 04:02:11  2018-10-08 00:00:00
# 1     2018-10-08 08:39:12  2018-10-08 06:04:00
# 2     2018-11-06 07:39:33  2018-11-05 19:07:00
# 3     2018-11-05 19:12:00  2018-11-05 19:07:00
# 4     2018-11-06 15:30:51  2018-11-06 00:00:00
# ...                   ...                  ...
# 3995  2023-01-11 07:53:51  2023-01-11 07:53:51
# 3996  2023-01-11 09:36:28  2023-01-11 09:18:00
# 3997  2023-01-11 09:45:43  2023-01-11 09:24:00
# 3998  2023-01-11 09:24:49  2023-01-11 09:24:49
# 3999  2023-01-11 10:32:15  2023-01-11 10:05:43
#
# [4000 rows x 12 columns]
