# %%
import requests
import pandas as pd

# %%
headers = {
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
'accept':'application/json',
'authorization': '6f64d6a047fad369d35c3806f8f8e0560475075a432585973f91caae35b4ad74'
} 

params = {
    'per_page': 1,
    'per_page': 1,
    'start_date': '',
    'end_date': '',
    'sort': '1'
}

id = '820' #Declaração do ID
url = 'https://app.inguru.me/api/v1/taxonomies/nodes/'+str(f'{id}')

response = requests.get(url, headers=headers, params=params)
print(response.json())
# Out:
# {'data': [{'id': 7867, 'created_at': '2021-03-26 09:12:29', 'updated_at': '2023-06-21 10:36:51', 'name': 'Investimento', 'expression': '(investimento OR investir* AND ("nova planta" OR "nova fábrica" OR "novo empreendimento" OR "nova unidade" OR "nova indústria")) NOT (bitcoin* OR "bolsa de valores")', 'initial_date': None, 'final_date': None, 'color': '#80B62E', 'children': [], 'links': {'news': 'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867'}}]}

# %%
number = 1
append_frame = pd.DataFrame()
while True:
    if response.json() is not None:

        headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
        'accept':'application/json',
        'authorization': '6f64d6a047fad369d35c3806f8f8e0560475075a432585973f91caae35b4ad74'
        } 

        params = {
            'per_page': 1000,
            'start_date': '',
            'end_date': '',
            'sort': 2
        }

        # Quando maior 'per_page' maior 'informations' menor total_pages

        #'pagination': {'total': 4555,
        #'count': 2000,
        #'per_page': 2000,
        #'current_page': 1,
        #'total_pages': 2,
        #'links': {'next_page': 'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867?page=2',
        #'previous_page': None}}}

        #id = '820' #Declaração do ID
        url = f'https://app.inguru.me/api/v1/taxonomies/nodes/news/8789?page={number}'

        response = requests.get(url, headers=headers, params=params)
        df = pd.json_normalize(response.json()['data'])
        append_frame = append_frame.append(df,ignore_index=True)

        print(response.json()['pagination']['total_pages'])
    number += 1
    if number > response.json()['pagination']['total_pages']:
        break

append_frame        
#display(append_frame)
# Out:
# 3
# 3
# 3
#              id                    domain  \
# 0     204502762       marechalnews.com.br
# 1     204498369          novocantu.com.br
# 2     204502368  www.jornalintegracao.com
# 3     204458106    divulgaempregos.com.br
# 4     204426490             iporanews.com
# ...         ...                       ...
# 2995   10261707       primeirahora.com.br
# 2996   10274635     www.expressomt.com.br
# 2997   10254933       correiocapixaba.com
# 2998   10233433          theworldnews.net
# 2999   10237404   www.folhavitoria.com.br
#
#                                                   title  \
# 0     Servidores da Saúde participam de ginástica la...
# 1     Servidores da Saúde participam de ginástica la...
# 2     Servidores da Saúde participam de ginástica la...
# 3     IFF abre processo seletivo para Técnico Segura...
# 4     Servidores da Saúde participam de ginástica la...
# ...                                                 ...
# 2995  Campanha destaca necessidade de prevenir acide...
# 2996  Mineradora de VG que utilizava mercúrio sem au...
# 2997                                        Publicações
# 2998  Campanha destaca necessidade de prevenir acide...
# 2999  Campanha destaca necessidade de prevenir acide...
#
#                                                subtitle         author  \
# 0     Durante cerca de 15 minutos, duas vezes por se...           None
# 1                                                        Redação Fonte
# 2     Durante cerca de 15 minutos, duas vezes por se...           None
# 3                                                                 None
# 4                                                                 None
# ...                                                 ...            ...
# 2995                                                              None
# 2996                                                              None
# 2997                                                              None
# 2998                                                              None
# 2999  Número de ocorrências caiu nos últimos anos, m...           None
#
#                                                 content  \
# 0     A Secretaria de Estado da Saúde (Sesa), por me...
# 1     A Secretaria de Estado da Saúde (Sesa), por me...
# 2     A Secretaria de Estado da Saúde (Sesa), por me...
# 3     Técnico Segurança do Trabalho\nRESPONSABILIDAD...
# 4     InícioEditoriasSaúdeServidores da Saúde partic...
# ...                                                 ...
# 2995  O governo federal, empresas e entidades sindic...
# 2996  Uma empresa de mineração localizada na zona ru...
# 2997  Campanha destaca necessidade de prevenir acide...
# 2998  O governo federal, empresas e entidades sindic...
# 2999  O governo federal, empresas e entidades sindic...
#
#                                                     url  \
# 0     https://marechalnews.com.br/noticia/78849/serv...
# 1     https://novocantu.com.br/noticia/159037/servid...
# 2     https://www.jornalintegracao.com/noticia/37922...
# 3     https://divulgaempregos.com.br/2023/07/iff-abr...
# 4     https://iporanews.com/2023/07/10/servidores-da...
# ...                                                 ...
# 2995  http://primeirahora.com.br/campanha-destaca-ne...
# 2996  http://www.expressomt.com.br/noticia/minerador...
# 2997  http://correiocapixaba.com/pt-BR/publicacoes/c...
# 2998  https://theworldnews.net/br-news/campanha-dest...
# 2999  https://www.folhavitoria.com.br/geral/noticia/...
#
#                        source source_country    source_state  \
# 0               Marechal News             br
# 1         Novo Cantu Notícias             br          Paraná
# 2           Jornal Integração             br          Paraná
# 3            Divulga Empregos             br           Bahia
# 4                  Iporã News             br          Paraná
# ...                       ...            ...             ...
# 2995            Primeira Hora             br     Mato Grosso
# 2996               EXPRESSOMT             br     Mato Grosso
# 2997         Correio Capixaba             br  Espírito Santo
# 2998  The World News - Brasil             br       São Paulo
# 2999   Folha Vitória (Online)             br  Espírito Santo
#
#              crawled_date       published_date
# 0     2023-07-11 09:27:20  2023-07-11 08:45:00
# 1     2023-07-11 08:57:31  2023-07-11 08:40:00
# 2     2023-07-11 09:22:01  2023-07-11 08:33:00
# 3     2023-07-11 04:03:21  2023-07-10 23:29:19
# 4     2023-07-10 18:38:11  2023-07-10 21:30:26
# ...                   ...                  ...
# 2995  2019-04-04 10:53:00  2019-04-04 10:45:36
# 2996  2019-04-04 16:01:53  2019-04-04 00:00:00
# 2997  2019-04-04 08:07:06  2019-04-04 00:00:00
# 2998  2019-04-03 20:07:55  2019-04-03 22:20:00
# 2999  2019-04-03 21:48:18  2019-04-03 21:08:10
#
# [3000 rows x 12 columns]

# %%
append_frame['crawled_date'].max()
# Out:
# '2023-07-11 09:27:20'

# %%
append_frame.sort_values(by='crawled_date', ascending=False)
# Out:
#              id                    domain  \
# 0     204554238             safras.com.br
# 2     204553983        www.bol.uol.com.br
# 7     204542861    faroldenoticias.com.br
# 11    204539950    clauderio.blogspot.com
# 1     204554299          br.investing.com
# ...         ...                       ...
# 9998   12103697      www.infomoney.com.br
# 9996   12102647  www.agenciaoglobo.com.br
# 9997   12102288    www.negociosemfoco.com
# 9995   12102280          www.terra.com.br
# 9999   12099578         www.otempo.com.br
#
#                                                   title  \
# 0     Topigs Norsvin realiza maior importação de mat...
# 2     Geely e Renault fecham acordo para desenvolver...
# 7     Confira a previsão de hoje (11/07) para seu signo
# 11                                 Horóscopo 11/07/2023
# 1     Geely e Renault fecham acordo para desenvolver...
# ...                                                 ...
# 9998  Hamburguerias ganham o paladar de pessoas que ...
# 9996  Hamburguerias ganham o paladar de pessoas que ...
# 9997  Hamburguerias ganham o paladar de pessoas que ...
# 9995  Hamburguerias ganham o paladar de pessoas que ...
# 9999  FCA anuncia investimento de R$ 7,5 bilhões na ...
#
#                                                subtitle        author  \
# 0                                                         Arno Baasch
# 2                                                                None
# 7                                                        Dani Cardoso
# 11                                                               None
# 1                                                                None
# ...                                                 ...           ...
# 9998  Os dados da pesquisa mostram que em média 50% ...          None
# 9996                                                             None
# 9997  Os dados da pesquisa mostram que em média 50% ...          None
# 9995  Os dados da pesquisa mostram que em média 50% ...          None
# 9999  Na próxima semana, Fiat-Chrysler Automóveis (F...          None
#
#                                                 content  \
# 0     Porto Alegre, 11 de julho de 2023 – Líder mund...
# 2     (Reuters) - A chinesa Geely e a montadora fran...
# 7     Foto: Arquivo/ Farol de Noticias\nPor Metrópol...
# 11    Áries (21/03 - 20/04)\nSupere desafios finance...
# 1     (Reuters) - A chinesa Geely e a montadora fran...
# ...                                                 ...
# 9998  Hambúrguer. Uma comida dificilmente rejeitada ...
# 9996  Negócio / Hambúrguer. Uma comida dificilmente ...
# 9997  Hambúrguer. Uma comida dificilmente rejeitada ...
# 9995  Hambúrguer. Uma comida dificilmente rejeitada ...
# 9999  Igor Veiga\n| igor.veiga@otempo.com.br\nA Fiat...
#
#                                                     url  \
# 0     https://safras.com.br/topigs-norsvin-realiza-m...
# 2     https://www.bol.uol.com.br/noticias/2023/07/11...
# 7     https://faroldenoticias.com.br/confira-a-previ...
# 11    http://clauderio.blogspot.com/2023/07/horoscop...
# 1     https://br.investing.com/news/stock-market-new...
# ...                                                 ...
# 9998  https://www.infomoney.com.br/negocios/noticias...
# 9996  http://www.agenciaoglobo.com.br/dinonews/Defau...
# 9997  https://www.negociosemfoco.com/newsdino/?relea...
# 9995  https://www.terra.com.br/noticias/dino/hamburg...
# 9999  https://www.otempo.com.br/super-motor/fca-anun...
#
#                                                  source source_country  \
# 0                                      Safras e Mercado             br
# 2                                                   BOL             br
# 7     Farol de Notícias – Referência em Jornalismo d...             br
# 11                                            Aconteceu             br
# 1                                         Investing.com             br
# ...                                                 ...            ...
# 9998                                          InfoMoney             br
# 9996                                    Agência O Globo             br
# 9997                                   Negócios em Foco             br
# 9995                                              Terra             br
# 9999                                            O Tempo             br
#
#            source_state                crawled_date       published_date
# 0     Rio Grande do Sul         2023-07-11 15:38:01  2023-07-11 18:28:03
# 2             São Paulo         2023-07-11 15:36:46  2023-07-11 15:26:00
# 7                               2023-07-11 14:08:59  2023-07-11 10:28:58
# 11                              2023-07-11 13:48:41  2023-07-11 08:22:00
# 1             São Paulo  2023-07-11 12:40:35.567221  2023-07-11 15:41:57
# ...                 ...                         ...                  ...
# 9998          São Paulo         2019-05-17 16:41:55  2019-05-17 15:55:00
# 9996     Rio de Janeiro         2019-05-17 16:15:13  2019-05-17 15:55:00
# 9997  Rio Grande do Sul         2019-05-17 16:03:49  2019-05-17 15:55:00
# 9995          São Paulo         2019-05-17 16:03:29  2019-05-17 15:58:00
# 9999          São Paulo         2019-05-17 14:54:28  2019-05-17 14:52:00
#
# [10000 rows x 12 columns]

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
'accept':'application/json',
'authorization': '6f64d6a047fad369d35c3806f8f8e0560475075a432585973f91caae35b4ad74'
} 

params = {
    'group_similar': 1,
    'per_page': 1,
    'start_date': '',
    'end_date': '',
    'sort': 2
}

# Quando maior 'per_page' maior 'informations' menor total_pages

#'pagination': {'total': 4555,
#'count': 2000,
#'per_page': 2000,
#'current_page': 1,
#'total_pages': 2,
#'links': {'next_page': 'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867?page=2',
#'previous_page': None}}}

#id = '820' #Declaração do ID
url = f'https://app.inguru.me/api/v1/taxonomies/nodes/news/7867?page=1'

response = requests.get(url, headers=headers, params=params)
df = pd.json_normalize(response.json()['data'])

# %%
df
# Out:
#           id                 domain  \
# 0  204515580  opresenterural.com.br
#
#                                                title subtitle author  \
# 0  Topigs Norsvin realiza a maior importação de m...            None
#
#                                              content  \
# 0  Líder mundial em pesquisa e desenvolvimento de...
#
#                                                  url            source  \
# 0  https://opresenterural.com.br/topigs-norsvin-r...  O Presente Rural
#
#   source_country source_state         crawled_date       published_date
# 0             br       Paraná  2023-07-11 11:02:23  2023-07-11 13:53:10

# %%
append_frame['crawled_date'].max()
# Out:
# '2023-07-11 11:02:23'
