# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Absenteismo.xlsx')
                   #, index_col=0)  

# Change all data types to strings
df = df.astype(str)

# %%
def remove_line_breaks(string):
    """
    Remove line breaks from a string.

    Args:
        string (str): The input string.

    Returns:
        str: The cleaned string.
    """
    string = string.replace('\r\n', ' ').replace('\n', ' ')
    return string

df = df.applymap(remove_line_breaks)
df = df.replace('nan', '', regex=True)

# %%
df.to_csv('absenteismo.csv', index=False, encoding='utf-8', sep=';')

# %%
df = pd.read_excel('BDD_Imagem.xlsx')
                   #, index_col=0)  

# Change all data types to strings
df = df.astype(str)


def remove_line_breaks(string):
    """
    Remove line breaks from a string.

    Args:
        string (str): The input string.

    Returns:
        str: The cleaned string.
    """
    string = string.replace('\r\n', ' ').replace('\n', ' ')
    return string

df = df.applymap(remove_line_breaks)
df = df.replace('nan', '', regex=True)
df.to_csv('BDD_Imagem.csv', index=False, encoding='utf-8', sep=';')







df = pd.read_excel('Microdados_Topofmind.xlsx')
                   #, index_col=0)  

# Change all data types to strings
df = df.astype(str)


def remove_line_breaks(string):
    """
    Remove line breaks from a string.

    Args:
        string (str): The input string.

    Returns:
        str: The cleaned string.
    """
    string = string.replace('\r\n', ' ').replace('\n', ' ')
    return string

df = df.applymap(remove_line_breaks)
df = df.replace('nan', '', regex=True)
df.to_csv('Microdados_Topofmind.csv', index=False, encoding='utf-8', sep=';')

# %%
import pandas as pd

def remove_commas(s):
    return s.replace('"', '')

df = df.applymap(remove_commas)

# %%
df.to_csv('data.csv', index=False, encoding='ISO-8859-1')

# %%
def clean_string(string):
    """
    Remove leading and trailing whitespaces and quotes from a string.

    Args:
        string (str): The input string.

    Returns:
        str: The cleaned string.
    """
    # Remove leading and trailing whitespaces
    string = string.strip()

    # Define the characters to remove
    chars_to_remove = ["'", '"']

    # Remove any remaining quotes
    for char in chars_to_remove:
        while string.startswith(char) or string.endswith(char):
            string = string.strip(char)

    return string

# %%
df.ano.unique().tolist()
# Out:
# [2023, 2022, 2021]

# %%
df.to_csv('absenteismo.csv',sep="|")

# %%
df = pd.read_excel('Absenteismo.xlsx')
                   #, index_col=0)  
df

# %%
import pandas as pd


# Define the cleaning function
def clean_string(string):
    """
    Remove leading and trailing whitespaces and quotes from a string.

    Args:
        string (str): The input string.

    Returns:
        str: The cleaned string.
    """
    # Remove leading and trailing whitespaces
    string = string.strip()

    # Define the characters to remove
    chars_to_remove = ["'", '"']

    # Remove any remaining quotes
    for char in chars_to_remove:
        while string.startswith(char) or string.endswith(char):
            string = string.strip(char)

    return string

# Apply the cleaning function to all strings in the dataframe
df = df.applymap(clean_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 29
#      26     return string
#      28 # Apply the cleaning function to all strings in the dataframe
# ---> 29 df = df.applymap(clean_string)
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\frame.py:7841, in DataFrame.applymap(self, func, na_action)
#    7838         return lib.map_infer(x, func, ignore_na=ignore_na)
#    7839     return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
# -> 7841 return self.apply(infer).__finalize__(self, "applymap")
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\frame.py:7765, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwds)
#    7754 from pandas.core.apply import frame_apply
#    7756 op = frame_apply(
#    7757     self,
#    7758     func=func,
#    (...)
#    7763     kwds=kwds,
#    7764 )
# -> 7765 return op.get_result()
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\apply.py:185, in FrameApply.get_result(self)
#     182 elif self.raw:
#     183     return self.apply_raw()
# --> 185 return self.apply_standard()
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\apply.py:276, in FrameApply.apply_standard(self)
#     275 def apply_standard(self):
# --> 276     results, res_index = self.apply_series_generator()
#     278     # wrap results
#     279     return self.wrap_results(results, res_index)
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\apply.py:290, in FrameApply.apply_series_generator(self)
#     287 with option_context("mode.chained_assignment", None):
#     288     for i, v in enumerate(series_gen):
#     289         # ignore SettingWithCopy here in case the user mutates
# --> 290         results[i] = self.f(v)
#     291         if isinstance(results[i], ABCSeries):
#     292             # If we have a view on v, we need to make a copy because
#     293             #  series_generator will swap out the underlying data
#     294             results[i] = results[i].copy(deep=False)
#
# File c:\Users\zhang.yuan\Miniconda3\envs\env_bot\lib\site-packages\pandas\core\frame.py:7839, in DataFrame.applymap.<locals>.infer(x)
#    7837 if x.empty:
#    7838     return lib.map_infer(x, func, ignore_na=ignore_na)
# -> 7839 return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#
# File pandas\_libs\lib.pyx:2467, in pandas._libs.lib.map_infer()
#
# Cell In[23], line 16, in clean_string(string)
#       6 """
#       7 Remove leading and trailing whitespaces and quotes from a string.
#       8
#    (...)
#      13     str: The cleaned string.
#      14 """
#      15 # Remove leading and trailing whitespaces
# ---> 16 string = string.strip()
#      18 # Define the characters to remove
#      19 chars_to_remove = ["'", '"']
#
# AttributeError: 'int' object has no attribute 'strip'

# %%
df = pd.read_csv('absenteismo.csv', sep="|")
                   #, index_col=0)  
df
# Out:
#       Unnamed: 0   ano      id                                     razao  \
# 0              0  2023  231039  A. C. D. A. IMPORTAÇÃO E EXPORTAÇÃO LTDA
# 1              1  2023  231017              AÇOUGUE E MERCEARIA MESQUITA
# 2              2  2023  231008                                 ACRE FRIO
# 3              3  2023  231027                          ACRE PUBLICIDADE
# 4              4  2023  231059                              ACRE SERVICE
# ...          ...   ...     ...                                       ...
# 4920        4920  2021  212295                                       NaN
# 4921        4921  2021  212322                                       NaN
# 4922        4922  2021  212358                                       NaN
# 4923        4923  2021  212359                                       NaN
# 4924        4924  2023  232000                 GC CONSTRUTORA LTDA - EPP
#
#            setor  dr en02       ap02  \
# 0       Comércio  AC  Sim  De acordo
# 1       Comércio  AC  Sim  De acordo
# 2       Serviços  AC  Sim  De acordo
# 3      Indústria  AC  Sim  De acordo
# 4       Comércio  AC  Não  De acordo
# ...          ...  ..  ...        ...
# 4920         NaN  TO  Sim  De acordo
# 4921         NaN  TO  Sim  De acordo
# 4922         NaN  TO  Sim  De acordo
# 4923         NaN  TO  Sim  De acordo
# 4924  Construção  AP  Sim  De acordo
#
#                                                    av01  \
# 0                                                 Outro
# 1                                                 Outro
# 2                                                 Outro
# 3                                                 Outro
# 4                                                   NaN
# ...                                                 ...
# 4920                      Proprietário/Sócio da empresa
# 4921  Supervisor Coordenador de área de Saúde e Segu...
# 4922  Engenheiro/Gestor/Técnico de Segurança do Trab...
# 4923      Profissional lotado no RH/Supervisor/Analista
# 4924                                              Outro
#
#                      av01_other  ...          av09_1          av09_2  \
# 0                 Gerente de RH  ...             NaN             NaN
# 1                       Gerente  ...             NaN             NaN
# 2                  Proprietário  ...  Não se alterou  Não se alterou
# 3                 Administrador  ...             NaN             NaN
# 4                           NaN  ...             NaN             NaN
# ...                         ...  ...             ...             ...
# 4920                        NaN  ...             NaN             NaN
# 4921                        NaN  ...             NaN             NaN
# 4922                        NaN  ...             NaN             NaN
# 4923                        NaN  ...             NaN             NaN
# 4924  Assistente Administrativo  ...             NaN             NaN
#
#         av09_3 av09_4          av09_5          av09_6          av09_7 av10  \
# 0          NaN    NaN        Não sabe             NaN        Não sabe   10
# 1          NaN    NaN        Aumentou             NaN             NaN   10
# 2     Melhorou    NaN  Não se alterou             NaN  Não se alterou   10
# 3          NaN    NaN         Reduziu             NaN        Aumentou    9
# 4          NaN    NaN             NaN             NaN             NaN  NaN
# ...        ...    ...             ...             ...             ...  ...
# 4920       NaN    NaN             NaN             NaN             NaN   10
# 4921       NaN    NaN             NaN             NaN             NaN   10
# 4922       NaN    NaN             NaN             NaN             NaN    9
# 4923       NaN    NaN             NaN             NaN             NaN    9
# 4924       NaN    NaN  Não se alterou  Não se alterou             NaN    7
#
#      av13 av14
# 0     NaN  Não
# 1     NaN  Sim
# 2     NaN  Sim
# 3     NaN  Sim
# 4     NaN  NaN
# ...   ...  ...
# 4920  NaN  NaN
# 4921  NaN  NaN
# 4922  NaN  NaN
# 4923  NaN  NaN
# 4924  NaN  Sim
#
# [4925 rows x 36 columns]
