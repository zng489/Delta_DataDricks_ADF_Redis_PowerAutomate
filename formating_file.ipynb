# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
df = pd.read_excel(r"C:\Users\zhang.yuan\Desktop\Painel da Agroindústria\Produtos Exportados.xlsx", skiprows=1)
df.to_csv('Produtos_Exportados.csv',  sep=';', index=False, encoding='utf-8')

# %%
df = pd.read_csv(r'Produtos_Exportados.csv')
df
# Out:
#                                 SETOR                SUBSETOR  \
# 0     ANIMAIS VIVOS (EXCETO PESCADOS)           ABELHAS VIVAS
# 1     ANIMAIS VIVOS (EXCETO PESCADOS)    AVES DE RAPINA VIVAS
# 2     ANIMAIS VIVOS (EXCETO PESCADOS)        AVESTRUZES VIVAS
# 3     ANIMAIS VIVOS (EXCETO PESCADOS)        AVESTRUZES VIVAS
# 4     ANIMAIS VIVOS (EXCETO PESCADOS)        AVESTRUZES VIVAS
# ...                               ...                     ...
# 3068                            SUCOS  SUCOS DE OUTRAS FRUTAS
# 3069                            SUCOS  SUCOS DE OUTRAS FRUTAS
# 3070                            SUCOS  SUCOS DE OUTRAS FRUTAS
# 3071                            SUCOS  SUCOS DE OUTRAS FRUTAS
# 3072                            SUCOS  SUCOS DE OUTRAS FRUTAS
#
#                        PRODUTO       NCM  \
# 0                ABELHAS VIVAS   1064100
# 1         AVES DE RAPINA VIVAS   1063100
# 2             AVESTRUZES VIVAS   1060010
# 3             AVESTRUZES VIVAS   1063310
# ...

# %%
df = pd.read_excel(r"C:\Users\zhang.yuan\Desktop\Painel da Agroindústria\Produtos Importados.xlsx", skiprows=1)
df.to_csv('Produtos_Importados.csv', index=False, sep=';', encoding='utf-8')

#df = pd.read_csv(r'Produtos_Importados.csv', sep=';')
