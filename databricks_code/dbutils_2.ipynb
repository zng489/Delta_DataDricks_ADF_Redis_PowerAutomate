# %%
#from cni_connectors import adls_gen1_connector as adls_conn
from pyspark.sql.window import Window
from pyspark.sql.functions import *
#from trs_control_field import trs_control_field as tcf
import json
import re


#var_adls_uri = adls_conn.adls_gen1_connect(spark, dbutils, scope="adls_gen1", #dynamic_overwrite="dynamic")
#var_adls_uri = adls_conn.adls_gen1_connect(spark, dbutils, scope="adls_gen1", #dynamic_overwrite="dynamic")

tables =  {
  "path_origin": "/usr/me/rais_estabelecimento",
  "path_destination":"/me/rais_estabelecimento"
}

dls = {"folders":{"landing":"/tmp/dev/lnd","error":"/tmp/dev/err","staging":"/tmp/dev/stg","log":"/tmp/dev/log","raw":"/tmp/dev/raw","trusted":"/tmp/dev/trs"}}
dls = {"folders":{"landing":"/lnd","error":"/err","staging":"/stg","log":"/log","raw":"/raw","trusted":"/trs"}}

adf = {
   'adf_factory_name': 'cnibigdatafactory', 
   'adf_pipeline_name': 'raw_trs_convenio_ensino_prof_carga_horaria',
   'adf_pipeline_run_id': 'p1',
   'adf_trigger_id': 't1',
   'adf_trigger_name': 'author_dev',
   'adf_trigger_time': '2020-10-14T15:00:06.0829994Z',
   'adf_trigger_type': 'Manual'
 }


raw = dls['folders']['raw']
trs = dls['folders']['trusted']


raw = dls['folders']['raw']
trs = dls['folders']['trusted']


var_adls_uri = 'abfss://datalake@cnibigdatadlsgen2.dfs.core.windows.net'
target = "{adl_path}{trs}{origin}".format(adl_path=var_adls_uri, trs=trs, origin=tables["path_destination"])
source = "{adl_path}{raw}{origin}".format(adl_path=var_adls_uri, raw=raw, origin=tables["path_origin"])
source
df = spark.read.parquet(source)

display(df.limit(5))


#df.printSchema()

#root
# |-- nm_arq_in: string (nullable = true)
# |-- ID_CEI_VINCULADO: long (nullable = true)
# |-- ID_CEPAO_ESTAB: double (nullable = true)
# |-- CD_CNAE10_CLASSE: integer (nullable = true)
# |-- ID_CNPJ_CEI: string (nullable = true)
# |-- ID_CNPJ_RAIZ: string (nullable = true)
# |-- DT_ABERTURA: integer (nullable = true)
# |-- DT_BAIXA: integer (nullable = true)
# |-- DT_ENCERRAMENTO: integer (nullable = true)
# |-- NM_EMAIL: string (nullable = true)
# |-- FL_IND_CEI_VINCULADO: integer (nullable = true)
# |-- FL_IND_ESTAB_PARTICIPA_PAT: integer (nullable = true)
# |-- FL_IND_RAIS_NEGAT: integer (nullable = true)
# |-- FL_IND_SIMPLES: integer (nullable = true)
# |-- CD_MUNICIPIO: integer (nullable = true)
# |-- CD_NATUREZA_JURIDICA: integer (nullable = true)
# |-- NM_LOGRADOURO: string (nullable = true)
# |-- NR_LOGRADOURO: double (nullable = true)
# |-- NM_BAIRRO: string (nullable = true)
# |-- NR_TELEFONE_EMPRE: long (nullable = true)
# |-- QT_VINC_ATIV: integer (nullable = true)
# |-- QT_VINC_CLT: integer (nullable = true)
# |-- QT_VINC_ESTAT: integer (nullable = true)
# |-- ID_RAZAO_SOCIAL: string (nullable = true)
# |-- CD_TAMANHO_ESTABELECIMENTO: integer (nullable = true)
# |-- CD_TIPO_ESTAB_ID: integer (nullable = true)
# |-- CD_IBGE_SUBSETOR: integer (nullable = true)
# |-- FL_IND_ATIV_ANO: integer (nullable = true)
# |-- CD_CNAE20_CLASSE: integer (nullable = true)
# |-- CD_CNAE20_SUBCLASSE: integer (nullable = true)
# |-- CD_UF: integer (nullable = true)
# |-- nr_reg: long (nullable = true)
# |-- dh_insercao_raw: timestamp (nullable = true)
# |-- dh_arq_in: timestamp (nullable = true)
# |-- ANO: integer (nullable = true)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nm_arq_in</th><th>ID_CEI_VINCULADO</th><th>ID_CEPAO_ESTAB</th><th>CD_CNAE10_CLASSE</th><th>ID_CNPJ_CEI</th><th>ID_CNPJ_RAIZ</th><th>DT_ABERTURA</th><th>DT_BAIXA</th><th>DT_ENCERRAMENTO</th><th>NM_EMAIL</th><th>FL_IND_CEI_VINCULADO</th><th>FL_IND_ESTAB_PARTICIPA_PAT</th><th>FL_IND_RAIS_NEGAT</th><th>FL_IND_SIMPLES</th><th>CD_MUNICIPIO</th><th>CD_NATUREZA_JURIDICA</th><th>NM_LOGRADOURO</th><th>NR_LOGRADOURO</th><th>NM_BAIRRO</th><th>NR_TELEFONE_EMPRE</th><th>QT_VINC_ATIV</th><th>QT_VINC_CLT</th><th>QT_VINC_ESTAT</th><th>ID_RAZAO_SOCIAL</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>CD_TIPO_ESTAB_ID</th><th>CD_IBGE_SUBSETOR</th><th>FL_IND_ATIV_ANO</th><th>CD_CNAE20_CLASSE</th><th>CD_CNAE20_SUBCLASSE</th><th>CD_UF</th><th>nr_reg</th><th>dh_insercao_raw</th><th>dh_arq_in</th><th>ANO</th></tr></thead><tbody><tr><td>ESTB2014.TXT</td><td>0</td><td>3.67E7</td><td>50504</td><td>12104589000157</td><td>12104589</td><td>21062010</td><td>21062010</td><td>0</td><td>SOTELDP@GMAIL.COM</td><td>0</td><td>0</td><td>0</td><td>0</td><td>313840</td><td>2062</td><td>RODOVIA BR</td><td>116.0</td><td>ZONA RURAL</td><td>32034414040</td><td>24</td><td>24</td><td>0</td><td>AT M AUTO POSTO LTDA</td><td>5</td><td>1</td><td>16</td><td>1</td><td>47318</td><td>4731800</td><td>null</td><td>34360023030</td><td>2020-10-23T17:08:34.000+0000</td><td>2020-10-06T15:54:49.866+0000</td><td>2014</td></tr><tr><td>ESTB2014.TXT</td><td>0</td><td>5.0050901E7</td><td>1465</td><td>07177560000165</td><td>07177560</td><td>19012005</td><td>19012005</td><td>0</td><td>ALSOBRAL@BOL.COM.BR</td><td>0</td><td>0</td><td>1</td><td>0</td><td>261160</td><td>2062</td><td>RUA DA AURORA</td><td>152.0</td><td>295</td><td>81032211855</td><td>0</td><td>0</td><td>0</td><td>DGD REPRESENTACOES LTDA</td><td>1</td><td>1</td><td>25</td><td>1</td><td>1598</td><td>159801</td><td>null</td><td>17180190338</td><td>2020-10-23T17:08:34.000+0000</td><td>2020-10-06T15:54:49.866+0000</td><td>2014</td></tr><tr><td>ESTB2014.TXT</td><td>0</td><td>8.507019E7</td><td>52442</td><td>07853184000181</td><td>07853184</td><td>21022006</td><td>21022006</td><td>0</td><td>VANDERLEIJBASTOS@HOTMAIL.COM</td><td>0</td><td>0</td><td>0</td><td>1</td><td>410940</td><td>2062</td><td>RUA PEDRO SIQUEIRA</td><td>772.0</td><td>SANTANA</td><td>42036237757</td><td>2</td><td>2</td><td>0</td><td>JSA MATERIAIS DE CONSTRUCAO LTDA ME</td><td>2</td><td>1</td><td>16</td><td>1</td><td>47440</td><td>4744099</td><td>null</td><td>128849122383</td><td>2020-10-23T17:08:34.000+0000</td><td>2020-10-06T15:54:49.866+0000</td><td>2014</td></tr><tr><td>ESTB2014.TXT</td><td>0</td><td>4.467E7</td><td>52418</td><td>96804778000122</td><td>96804778</td><td>20071993</td><td>3112005</td><td>0</td><td>CONTEMAC.CONTABILIDADEFSA@GMAIL.COM</td><td>0</td><td>0</td><td>1</td><td>1</td><td>290150</td><td>2062</td><td>RUA DR JACKSON DO AMAURY</td><td>10.0</td><td>CENTRO</td><td>75036235636</td><td>0</td><td>0</td><td>0</td><td>FARMACIA RENASCER LTDA</td><td>1</td><td>1</td><td>16</td><td>1</td><td>47717</td><td>4771701</td><td>null</td><td>25770078642</td><td>2020-10-23T17:08:34.000+0000</td><td>2020-10-06T15:54:49.866+0000</td><td>2014</td></tr><tr><td>ESTB2014.TXT</td><td>0</td><td>1.392E7</td><td>52434</td><td>01304554000145</td><td>01304554</td><td>4071996</td><td>3112005</td><td>0</td><td>ECRUZEIRO@UOL.COM.BR</td><td>0</td><td>0</td><td>0</td><td>1</td><td>353710</td><td>2135</td><td>RUA JOAO NIERO</td><td>403.0</td><td>JARDIM TRIUNFO</td><td>19038932746</td><td>5</td><td>5</td><td>0</td><td>RUBENS G HUTTEMBERGUE ARTESANATOS ME</td><td>3</td><td>1</td><td>16</td><td>1</td><td>47598</td><td>4759899</td><td>null</td><td>77309504591</td><td>2020-10-23T17:08:34.000+0000</td><td>2020-10-06T15:54:49.866+0000</td><td>2014</td></tr></tbody></table></div>

# %% [markdown]
# ### df.filter | select | when(condition) [#]

# %%
# >> df.select('ANO').distinct().collect()
# >> Out[20]: [Row(ANO=2018), Row(ANO=2015), Row(ANO=2014), Row(ANO=2016), Row(ANO=2017)]
  
from pyspark.sql.functions import col

df_greater_or_equal_than_2018 = df.filter(col('ANO') == 2018).select(['ID_CNPJ_CEI',
                                                                      'ID_RAZAO_SOCIAL',
                                                                      'CD_CNAE10_CLASSE',
                                                                      'CD_CNAE20_CLASSE',
                                                                      'CD_TAMANHO_ESTABELECIMENTO',
                                                                      'CD_UF',
                                                                      'CD_MUNICIPIO',
                                                                      'QT_VINC_ATIV'])




DF_SELECTED = df_greater_or_equal_than_2018.withColumn('PORTE_ESTABELECIMENTO',
                                                when((col('CD_TAMANHO_ESTABELECIMENTO') >= '1') & (col('CD_TAMANHO_ESTABELECIMENTO') <= '3'),
                                                'MICRO').when((col('CD_TAMANHO_ESTABELECIMENTO') >= '4') & (col('CD_TAMANHO_ESTABELECIMENTO') <= '6'),
                                                'PEQUENA').when((col('CD_TAMANHO_ESTABELECIMENTO') >= '7') & (col('CD_TAMANHO_ESTABELECIMENTO') <= '8'),
                                                'MÉDIA').when((col('CD_TAMANHO_ESTABELECIMENTO') >= '9') & (col('CD_TAMANHO_ESTABELECIMENTO') <= '10'),
                                                'GRANDE').otherwise(df_greater_or_equal_than_2018.CD_TAMANHO_ESTABELECIMENTO)).withColumn('CD_UF', substring('CD_MUNICIPIO', 1,2))
display(DF_SELECTED.limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_CNPJ_CEI</th><th>ID_RAZAO_SOCIAL</th><th>CD_CNAE10_CLASSE</th><th>CD_CNAE20_CLASSE</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>CD_UF</th><th>CD_MUNICIPIO</th><th>QT_VINC_ATIV</th><th>PORTE_ESTABELECIMENTO</th></tr></thead><tbody><tr><td>00700041697886</td><td>JOSE CARLOS MORESCHI-</td><td>1155</td><td>1156</td><td>2</td><td>50</td><td>500570</td><td>2</td><td>MICRO</td></tr><tr><td>07696009000128</td><td>LAVANDERIA INDUSTRIAL AURORA LTDA</td><td>93017</td><td>96017</td><td>4</td><td>43</td><td>430460</td><td>19</td><td>PEQUENA</td></tr><tr><td>08633739000142</td><td>BELCARGAS TRASNPORTADORA LTDA</td><td>60267</td><td>49302</td><td>1</td><td>41</td><td>410840</td><td>0</td><td>MICRO</td></tr></tbody></table></div>

# %% [markdown]
# ### spark.createDataFrame(pd.read_csv | withColumn(substring) | withColumnRenamed

# %%
import pandas as pd

DF_MUNICIPIOS_M = spark.createDataFrame(pd.read_csv('https://raw.githubusercontent.com/leogermani/estados-e-municipios-ibge/master/municipios.csv')).withColumn('COD', substring('COD', 1,6)).withColumnRenamed("COD", "COD_MUNICIPIOS_M").withColumnRenamed("NOME", "NOME_MUNICIPIOS_M").withColumnRenamed("COD UF", "COD_UF_M")
# display(DF_MUNICIPIOS_M)


DF_UF = spark.createDataFrame(pd.read_csv('https://raw.githubusercontent.com/leogermani/estados-e-municipios-ibge/master/estados.csv')).withColumnRenamed("COD", "COD_UF_UF").withColumnRenamed("NOME", "NOME_UF_UF")
# display(df_uf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### df_1.join(df_2, df_1['Column'] == df_2['Column'])

# %%
MATCHING_MUNICIPIOS = DF_SELECTED.join(DF_MUNICIPIOS_M , DF_SELECTED['CD_MUNICIPIO'] == DF_MUNICIPIOS_M['COD_MUNICIPIOS_M'])
display(MATCHING_MUNICIPIOS.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_CNPJ_CEI</th><th>ID_RAZAO_SOCIAL</th><th>CD_CNAE10_CLASSE</th><th>CD_CNAE20_CLASSE</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>CD_UF</th><th>CD_MUNICIPIO</th><th>QT_VINC_ATIV</th><th>PORTE_ESTABELECIMENTO</th><th>COD_UF_M</th><th>COD_MUNICIPIOS_M</th><th>NOME_MUNICIPIOS_M</th></tr></thead><tbody><tr><td>04945341005079</td><td>COMPANHIA DE SANEAMENTO DO PARA</td><td>41009</td><td>36006</td><td>2</td><td>15</td><td>150300</td><td>1</td><td>MICRO</td><td>15</td><td>150300</td><td>Faro</td></tr><tr><td>07191823000190</td><td>JULIO DE CARVALHO PINTO</td><td>52132</td><td>47121</td><td>1</td><td>15</td><td>150300</td><td>0</td><td>MICRO</td><td>15</td><td>150300</td><td>Faro</td></tr><tr><td>14474676000121</td><td>ELMA C FARIAS ME</td><td>52132</td><td>47121</td><td>1</td><td>15</td><td>150300</td><td>0</td><td>MICRO</td><td>15</td><td>150300</td><td>Faro</td></tr><tr><td>08850634000145</td><td>CONS E E M E F MARIA DO FARO LOPES CHAVES</td><td>74160</td><td>85503</td><td>1</td><td>15</td><td>150300</td><td>0</td><td>MICRO</td><td>15</td><td>150300</td><td>Faro</td></tr><tr><td>10938253000164</td><td>ASSOCIACA D P E M D E M D E I N SENHORA DAS GRACAS</td><td>91995</td><td>94995</td><td>1</td><td>15</td><td>150300</td><td>0</td><td>MICRO</td><td>15</td><td>150300</td><td>Faro</td></tr></tbody></table></div>

# %%
MATCHING_UF = MATCHING_MUNICIPIOS.join(DF_UF, MATCHING_MUNICIPIOS['CD_UF'] == DF_UF['COD_UF_UF'])
display(MATCHING_UF.limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_CNPJ_CEI</th><th>ID_RAZAO_SOCIAL</th><th>CD_CNAE10_CLASSE</th><th>CD_CNAE20_CLASSE</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>CD_UF</th><th>CD_MUNICIPIO</th><th>QT_VINC_ATIV</th><th>PORTE_ESTABELECIMENTO</th><th>COD_UF_M</th><th>COD_MUNICIPIOS_M</th><th>NOME_MUNICIPIOS_M</th><th>COD_UF_UF</th><th>NOME_UF_UF</th><th>SIGLA</th></tr></thead><tbody><tr><td>23082785000194</td><td>PAULO V. DE SOUZA -ME</td><td>52132</td><td>47121</td><td>1</td><td>26</td><td>260010</td><td>0</td><td>MICRO</td><td>26</td><td>260010</td><td>Afogados da Ingazeira</td><td>26</td><td>Pernambuco</td><td> PE</td></tr><tr><td>10573994000199</td><td>ALEX SANDRA O M DA SILVA ME</td><td>50105</td><td>45129</td><td>2</td><td>26</td><td>260010</td><td>2</td><td>MICRO</td><td>26</td><td>260010</td><td>Afogados da Ingazeira</td><td>26</td><td>Pernambuco</td><td> PE</td></tr><tr><td>16977615000102</td><td>ASSOC AGROELOGICA DO PAGEU-ASAP DE CERTIFICACAO</td><td>91995</td><td>94308</td><td>1</td><td>26</td><td>260010</td><td>0</td><td>MICRO</td><td>26</td><td>260010</td><td>Afogados da Ingazeira</td><td>26</td><td>Pernambuco</td><td> PE</td></tr></tbody></table></div>

# %% [markdown]
# ### df.select | withColumnRenamed

# %%
MATCHING = MATCHING_UF.select(['ID_CNPJ_CEI', 'ID_RAZAO_SOCIAL', 'CD_CNAE10_CLASSE', 'CD_CNAE20_CLASSE', 'CD_TAMANHO_ESTABELECIMENTO', 'PORTE_ESTABELECIMENTO', 'CD_UF', 'NOME_UF_UF', 'SIGLA', 'CD_MUNICIPIO' , 'NOME_MUNICIPIOS_M', 'QT_VINC_ATIV']).withColumnRenamed("NOME_UF_UF", "NOME_UF").withColumnRenamed("NOME_MUNICIPIOS_M", "NOME_MUNICIPIO")


display(MATCHING)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_CNPJ_CEI</th><th>ID_RAZAO_SOCIAL</th><th>CD_CNAE10_CLASSE</th><th>CD_CNAE20_CLASSE</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>PORTE_ESTABELECIMENTO</th><th>CD_UF</th><th>NOME_UF</th><th>SIGLA</th><th>CD_MUNICIPIO</th><th>NOME_MUNICIPIO</th><th>QT_VINC_ATIV</th></tr></thead><tbody><tr><td>23082785000194</td><td>PAULO V. DE SOUZA -ME</td><td>52132</td><td>47121</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>10573994000199</td><td>ALEX SANDRA O M DA SILVA ME</td><td>50105</td><td>45129</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>2</td></tr><tr><td>16977615000102</td><td>ASSOC AGROELOGICA DO PAGEU-ASAP DE CERTIFICACAO</td><td>91995</td><td>94308</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>07096834000191</td><td>JULIO CESAR VILELA DANTAS ME</td><td>72303</td><td>63119</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>05286288000126</td><td>ASSOCIACAO DE SAUDE DO VALE DO PAJEU</td><td>85162</td><td>86909</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>11999184000161</td><td>T H P TECIDOS E CONFECCOES LTDA</td><td>52310</td><td>47555</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>4</td></tr><tr><td>12600714000110</td><td>AUTO POSTO BRASILINO LTDA</td><td>50504</td><td>47318</td><td>4</td><td>PEQUENA</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>11</td></tr><tr><td>16382362000124</td><td>VALERIO CONSTRUCOES LTDA ME</td><td>52442</td><td>47440</td><td>3</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>5</td></tr><tr><td>01437408001321</td><td>INSTITUTO NORDESTE CIDADANIA</td><td>91995</td><td>94995</td><td>4</td><td>PEQUENA</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>11</td></tr><tr><td>15087582000162</td><td>EVERALDO F DA SILVA ME</td><td>50300</td><td>45307</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>1</td></tr><tr><td>10572071000384</td><td>SECRETARIA DE EDUCACAO E ESPORTES</td><td>80144</td><td>85121</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>11402291000160</td><td>POMPILHO LEITE DE QUEIROZ</td><td>15814</td><td>10911</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>4</td></tr><tr><td>21842374000124</td><td>W L M DE MORAIS VERAS ME</td><td>15814</td><td>10911</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>3</td></tr><tr><td>30984655000102</td><td>W H S DOS SANTOS BARROS</td><td>70106</td><td>41107</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>1</td></tr><tr><td>23405635000174</td><td>F & D COSMETICOS</td><td>52418</td><td>47725</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>35667419000186</td><td>PAPELARIA SERVICON LTDA ME</td><td>52469</td><td>47610</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>28196071000120</td><td>ASSOCIACAO DOS AMIGOS E PROTETORES DE ANIMAIS DE AFO</td><td>91995</td><td>94995< ...

# %% [markdown]
# ### Saving Files | df.coalesce(1).write.format('csv').option("header","true").save( )

# %%
#MATCHING.coalesce(1).write.format('csv').option("header","true").save("abfss://datalake@cnibigdatadlsgen2.dfs.core.windows.net/uds/uniepro/data/Juca_Rais_Estabelecimento.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(MATCHING.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_CNPJ_CEI</th><th>ID_RAZAO_SOCIAL</th><th>CD_CNAE10_CLASSE</th><th>CD_CNAE20_CLASSE</th><th>CD_TAMANHO_ESTABELECIMENTO</th><th>PORTE_ESTABELECIMENTO</th><th>CD_UF</th><th>NOME_UF</th><th>SIGLA</th><th>CD_MUNICIPIO</th><th>NOME_MUNICIPIO</th><th>QT_VINC_ATIV</th></tr></thead><tbody><tr><td>23082785000194</td><td>PAULO V. DE SOUZA -ME</td><td>52132</td><td>47121</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>10573994000199</td><td>ALEX SANDRA O M DA SILVA ME</td><td>50105</td><td>45129</td><td>2</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>2</td></tr><tr><td>16977615000102</td><td>ASSOC AGROELOGICA DO PAGEU-ASAP DE CERTIFICACAO</td><td>91995</td><td>94308</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>07096834000191</td><td>JULIO CESAR VILELA DANTAS ME</td><td>72303</td><td>63119</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr><tr><td>05286288000126</td><td>ASSOCIACAO DE SAUDE DO VALE DO PAJEU</td><td>85162</td><td>86909</td><td>1</td><td>MICRO</td><td>26</td><td>Pernambuco</td><td> PE</td><td>260010</td><td>Afogados da Ingazeira</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### groupBy | agg | sum
#
# ```python
# GroupBy on multiple columns
# df.groupBy("department","state") \
#     .sum("salary","bonus") \
#     .show(false)
# ```

# %%
MATCHING.groupBy('ID_RAZAO_SOCIAL').agg(sum('CD_TAMANHO_ESTABELECIMENTO')).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------------------+
#      ID_RAZAO_SOCIAL|sum(CD_TAMANHO_ESTABELECIMENTO)|
# +--------------------+-------------------------------+
#    ANGELO E CIA LTDA|                              2|
# PAULO ADRIANO BES...|                              1|
# NUBIA SOARES DA S...|                              1|
# LUANA RODRIGUES D...|                              2|
# ELETROPETRO MOTOS...|                              5|
# +--------------------+-------------------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### df.withColumn( ,when((col, 'list comprehension').otherwise)

# %%
df.withColumn('New_Name_Column', when((col('column'))))
df_matched = df.select([col(c).alias(dict_items_SEM_N_A.get(c,c)) for c in df.columns])
display(df_matched.limit(4))

# %% [markdown]
# # dbutils.fs.rm(..., True )

# %%
# dbutils.help()
dbutils.fs.rm('dbfs:/ZY/zhang', True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: True</div>

# %% [markdown]
# # spark.table | Database Tables

# %%
table_test = spark.table("dmfiep.dim_setor")
display(table_test.select("*"))

# %% [markdown]
# # Saving('dbfs:') | spark.read

# %%
FILE_NAME.coalesce(1).write.mode('overwrite').partitionBy('ur_partition').save('dbfs:/ZY/zhang', format="csv")

#prm = spark.read\
#.format("csv")\
#.option("header","true")\
#.option('sep', ';')\
#.load('dbfs:/ZY/zhang')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
