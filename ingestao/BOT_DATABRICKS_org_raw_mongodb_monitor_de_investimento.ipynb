# %%
from cni_connectors import adls_gen1_connector as adls_conn
var_adls_uri = adls_conn.adls_gen1_connect(spark, dbutils, scope="adls_gen2", dynamic_overwrite="dynamic")
# Out:
# fornecedor_dev
# dev-execution

# %%
import os
import requests, zipfile
import shutil
import pandas as pd
import glob
import subprocess
from threading import Timer
import shlex
import logging
import json
from core.bot import log_status
# drop_directory is not allowed in the databricks
from core.adls import upload_file
import pyspark.sql.functions as f
import re
import shlex
import time
from time import strftime
from datetime import datetime
from datetime import datetime, date
from unicodedata import normalize
from collections import namedtuple
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, BooleanType
import warnings
warnings.simplefilter('ignore')

# %%
import pyarrow.parquet as pa

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /local_disk0/.ephemeral_nfs/envs/pythonEnv-c5c10925-03be-4486-8d78-2ab153c9451a/lib/python3.9/site-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-c5c10925-03be-4486-8d78-2ab153c9451a/lib/python3.9/site-packages (from pymongo) (2.7.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-c5c10925-03be-4486-8d78-2ab153c9451a/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install motor
# Out:
# Collecting motor
#   Downloading motor-3.6.0-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 2.4 MB/s
# Collecting pymongo<4.10,>=4.9
#   Downloading pymongo-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 59.4 MB/s
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-c5c10925-03be-4486-8d78-2ab153c9451a/lib/python3.9/site-packages (from pymongo<4.10,>=4.9->motor) (2.7.0)
# Installing collected packages: pymongo, motor
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.10.1
#     Uninstalling pymongo-4.10.1:
#       Successfully uninstalled pymongo-4.10.1
# Successfully installed motor-3.6.0 pymongo-4.9.2
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-c5c10925-03be-4486-8d78-2ab153c9451a/bin/python -m pip install --upgrade pip' command.

# %%
adf = {"adf_factory_name":"cnibigdatafactory","adf_pipeline_name":"lnd_org_raw_trello_enterprise_board_organizations","adf_pipeline_run_id":"3fdd924e-d24d-4644-bc5e-68cb000d7849","adf_trigger_id":"6e3289dc8859437888605e22c1ba7e40","adf_trigger_name":"Sandbox","adf_trigger_time":"2024-01-08T13:22:21.2585028Z","adf_trigger_type":"Manual"}

bot_name = 'org_raw_mongodb_monitor_de_investimento'

dls = {"folders":{"landing":"/tmp/dev/lnd","error":"/tmp/dev/err","archive":"/tmp/dev/ach","staging":"/tmp/dev/stg","log":"/tmp/dev/log","raw":"/tmp/dev/raw","trusted":"/tmp/dev/trs","business":"/tmp/dev/biz","prm":"/tmp/dev/prm","historico":"/tmp/dev/hst"},"path_prefix":"tmp","uld":{"folders":{"landing":"/tmp/dev/uld","error":"/tmp/dev/err","staging":"/tmp/dev/stg","log":"/tmp/dev/log","raw":"/tmp/dev/raw","archive":"/tmp/dev/ach"},"systems":{"raw":"usr"},"path_prefix":"/tmp/dev/"},"systems":{"raw":"usr"}}

env = "{\"env\":\"dev\"}"

# %%
dbutils.widgets.text("user_parameters", '{"null": "null"}')
dbutils.widgets.text("env", 'dev')
dbutils.widgets.text("storage", '{"url": "https://cnibigdatadlsgen2.dfs.core.windows.net", "container": "datalake"}')

# %%
### params = json.loads(re.sub("\'", '\"', dbutils.widgets.get("params")))
### dls = json.loads(re.sub("\'", '\"', dbutils.widgets.get("dls")))
### adf = json.loads(re.sub("\'", '\"', dbutils.widgets.get("adf")))

# %%
import asyncio
from motor.motor_asyncio import AsyncIOMotorClient
import pandas as pd
from pyspark.sql import SparkSession

var_adls_uri = "abfss://datalake@cnibigdatadlsgen2.dfs.core.windows.net"
var_path_file = "/uds/oni/observatorio_nacional/monitor_investimentos/mongoDB/cadastro/"
var_sink = var_adls_uri + var_path_file

connection_string = "mongodb+srv://produtooni:Pvkhg05I1gOT0FWc@monitorinvest.nttgenh.mongodb.net/monitorinvest?retryWrites=true&w=majority"

async def fetch_documents():
    client = AsyncIOMotorClient(connection_string)
    db = client['monitor_investimento']
    collection = db['cadastro']

    documents = await collection.find().to_list(None)  # Fetch all documents
    client.close()
    return documents

async def process_and_save():
    documents = await fetch_documents()
    df = pd.DataFrame(documents)
    df['_id'] = df['_id'].astype(str)
    df['historico'] = df['historico'].apply(lambda x: str(x) if isinstance(x, list) else x)
    df['municipios'] = df['municipios'].apply(lambda x: str(x) if not isinstance(x, str) else x)
    df['cnpj_basico'] = df['cnpj_basico'].astype(str)
    df['setor_empresa'] = df['setor_empresa'].apply(lambda x: str(x) if not isinstance(x, str) else x)

    if not df.empty:
        pyspark_df = spark.createDataFrame(df)
    return df
        #pyspark_df.write.format('parquet').save(var_sink, mode='overwrite')

# %%
# get pandasframes from await process_and_save()
# await process_and_save()

# %%
# Example from trello

# tmp = 'trello/'
# tmp_customfields = tmp + 'trello__customfields'

# PandasFrame = pd.read_parquet(f'{tmp_customfields}') 
# PandasFrame = pd.read_parquet('trello/trello__customfields')

# Desnecessário tmp_log = tmp + 'trello__log'

# %%
tmp_mongodb_monitor_de_investimento = "mongodb_monitor_de_investimento"
os.makedirs(tmp_mongodb_monitor_de_investimento, mode=0o777, exist_ok=True)

shutil.rmtree(tmp_mongodb_monitor_de_investimento)

# %%
# %ls
# Out:
# mongodb_monitor_de_investimento/
# org_raw_abstartups_lista_startups*
# org_raw_anprotec_mapa_associados*
# org_raw_bacen_estban_mensal_municipios*
# org_raw_banco_mundial_indicadores_selecionados*
# org_raw_banco_mundial_preco_commodity*
# org_raw_bndes_operacoes_indiretas_automaticas*
# org_raw_bndes_operacoes_nao_automaticas*
# org_raw_camara_dep_dados_abertos_atividade_parlamentar*
# org_raw_camara_dep_dados_abertos_deputados*
# org_raw_camara_dep_dados_abertos_eventos*
# org_raw_camara_dep_dados_abertos_frentes_parlament*
# org_raw_camara_dep_dados_abertos_funcionarios*
# org_raw_camara_dep_dados_abertos_tesauro*
# org_raw_capes_cursos_pos_graduacao*
# org_raw_capes_publicacoes*
# org_raw_cgu_transparencia_contratacoes*
# org_raw_cnpq_financiamento_entidade_ensino*
# org_raw_confap_agencias_fomento*
# org_raw_consumo_prod*
# org_raw_cwts_top_10_publicacoes*
# org_raw_embrapa_unidade_embrapa_brasil*
# org_raw_estrutura_territorial*
# org_raw_finep_atlas_fin_nao_reembolsavel*
# org_raw_finep_indicadores_finaciamento*
# org_raw_gera_energia_distribuida*
# org_raw_inpi_badepi_patentes*
# org_raw_inse_nivel_socioeconomico*
# org_raw_ipca*
# org_raw_jira_issue*
# org_raw_log_analytics*
# org_raw_logs_adf*
# org_raw_logs_blob_storage*
# org_raw_mcti_empresas_lei_do_bem*
# org_raw_mcti_inovadata_companies*
# org_raw_mcti_pnipe_laboratorios*
# org_raw_mongodb_monitor_de_investimento*
# org_raw_mpt_sst_indicadores_uni*
# org_raw_ms_sinan_acbi*
# org_raw_ms_sinan_acgr*
# org_raw_ms_sinan_anim*
# org_raw_ms_sinan_canc*
# org_raw_ms_sinan_derm*
# org_raw_ms_sinan_iexo*
# org_raw_ms_sinan_lerd*
# org_raw_ms_sinan_ment*
# org_raw_ms_sinan_pair*
# org_raw_ms_sinan_pneu*
# org_raw_mtp_aeat_acid_obi_mun*
# org_raw_mtp_aeat_conseq_clas*
# org_raw_mtp_aeat_conseq_div*
# org_raw_mtp_aeat_motivo_cid*
# org_raw_mtp_aeat_motivo_class*
# org_raw_mtp_aeat_motivo_div*
# org_raw_mtp_aeat_motivo_ida_sex*
# org_raw_openstartups_top_all_100*
# org_raw_openstartups_top_categorias_10*
# org_raw_rfb_cno*
# org_raw_sgc_iron*
# org_raw_sgc_vacinas*
# org_raw_trello_customfields*
# org_raw_trello_enterprise_board_organizations*
# org_raw_trello_list_checklist*
# org_raw_trello_member_actions_card*
# org_raw_un_comtrade_comer_wld*
# org_raw_un_comtrade_partner*
# org_raw_un_comtrade_reporter*

# %%
df.to_parquet('mongodb_monitor_de_investimento/mongo_monitor.parquet', compression='snappy')

# %%
# %ls mongodb_monitor_de_investimento/
# Out:
# mongo_monitor.parquet*

# %%
table = pa.read_table('mongodb_monitor_de_investimento/mongo_monitor.parquet') 
table
# Out:
# Out[45]: pyarrow.Table
# _id: string
# dt_anuncio: string
# cnpj_nao_existe: bool
# cnpj_basico: string
# nome_empresa: list<item: string>
#   child 0, item: string
# uf: list<item: string>
#   child 0, item: string
# setor_investimento: list<item: string>
#   child 0, item: string
# setor_empresa: string
# objetivo: string
# desc: string
# novo_pac: bool
# moeda: string
# valor: double
# unidade_valor: string
# fonte: list<item: struct<portal: string, titulo: string, url: string>>
#   child 0, item: struct<portal: string, titulo: string, url: string>
#       child 0, portal: string
#       child 1, titulo: string
#       child 2, url: string
# origem_recurso: string
# nome_responsavel: string
# dia_hora_preenchimento: string
# historico: string
# municipios: string
# ano_conclusao: string
# ano_inicio: string
# ----
# setor_investimento: [[["Extração de petróleo e gás natural"],["Armazenamento e atividades auxiliares dos transportes"],["Armazenamento e atividades auxiliares dos transportes"],["Transporte terrestre"],["Transporte terrestre"],["Atividades de atenção à saúde humana"],["Transporte terrestre"],["Administração pública, defesa e seguridade social"],["Eletricidade, gás e outras utilidades"],["Fabricação de equipamentos de informática, produtos eletrônicos e ópticos"],...,["Eletricidade, gás e outras utilidades"],["Atividades de serviços financeiros"],["Obras de infraestrutura"],["Obras de infraestrutura"],["Eletricidade, gás e outras utilidades"],["Fabricação de produtos alimentícios"],["Armazenamento e atividades auxiliares dos transportes"],["Transporte terrestre"],["Fabricação de veículos automotores, reboques e carrocerias"],["Fabricação de veículos automotores, reboques e carrocerias"]]]
# setor_empresa: [["['0600001']","['6462000']","['6462000']","['8411600']","['8411600']","['8411600']","['8411600']","['8411600']","['3511501']","['2621300']",...,"['3512300']","['6462000']","['5120000', '5250804']","['4661300']","nan","['1093701']","['5232000']","['6462000', '8219999']","['2910701']","['2910701']"]]
# objetivo: [["Construção/Implantação","Ampliação/modernização","Construção/Implantação","Construção/Implantação","Construção/Implantação","Ampliação/modernização","Construção/Implantação","Ampliação/modernização","Ampliação/modernização","Ampliação/modernização",...,"Ampliação/modernização","Ampliação/modernização","Ampliação/modernização","Ampliação/modernização","Construção/Implantação","Ampliação/modernização","Venda/Concessão/Desestatização","Venda/Concessão/Desestatização","Ampliação/modernização","Ampliação/modernização"]]
# desc: [["O diretor de Exploração e Produção da Petrobras (PETR3; PETR4), Joelson Falcão Mendes, afirmou nesta segunda-feira (2), que a companhia deverá investir cerca de US$ 300 milhões na perfuração de dois poços exploratórios de petróleo e gás em águas profundas da Bacia Potiguar, cujas licenças ambientais foram emitidas pelo Ibama.
# Nesse sentido, a licença do Ibama representa a primeira desde 2013 concedida para perfuração na Margem Equatorial brasileira, uma extensa área que vai do Rio Grande do Norte ao Amapá, considerada uma nova fronteira exploratória de petróleo e gás.","A TIL (Terminal Investment Limited), do grupo de navegação MSC, prevê investimento de R$ 7 bilhões em seus terminais portuários no Brasil, pelos próximos cinco anos. O valor poderá mais do que dobrar a depender das oportunidades de expansão, segundo Ammar Kanaan, presidente global da companhia. Ao todo, o grupo teria R$ 17 bilhões reservados a negócios no país.
# Entre os investimentos já aprovados, R$ 4 bilhões se referem ao BTP, terminal de contêineres no Porto de Santos (SP) que a empresa opera em sociedade com a APM Terminals, da Maersk.","A TIL (Terminal Investment Limited), do grupo de navegação MSC, prevê investimento de R$ 7 bilhões em seus terminais portuários no Brasil, pelos próximos cinco anos. O valor poderá mais do que dobrar a depender das oportunidades de expansão, segundo Ammar Kanaan, presidente global da companhia. Ao todo, o grupo teria R$ 17 bilhões reservados a negócios no país. Para além dos investimentos em Santos, a TIL planeja alocar cerca de R$ 3 bilhões em seu terminal de contêineres no Porto de Navegantes, terminal privado operado na região de Itajaí (SC). ","O Governo do Estado, por meio do Programa Asfalta Amazonas, vai investir aproximadamente R$ 14 milhões na recuperação asfáltica do sistema viário de Novo Aripuanã.
#
# O governo será responsável por pagar cerca de R$ 9 bilhões dos R$ 13,5 bilhões a serem investidos em infraestrutura. Parte dos recursos estaduais será oriunda de empréstimo de R$ 6,4 bilhões com o Banco Nacional de Desenvolvimento Econômico e Social (BNDES).
#
# A empresa vencedora do leilão também passará a ser responsável pela Linha 7-Rubi, atualmente sob gestão da Companhia Paulista de Transportes Metropolitanos (CPTM), ligando a estação Barra Funda a Jundiaí e passando por 17 estações. Na nova versão do projeto, o valor total do investimento previsto subiu de R$ 12,8 bilhões para R$ 13,5 bilhões.","A Volkswagen do Brasil lançará 16 novos veículos até 2028, incluindo modelos híbridos, 100% elétricos e Total Flex.
#
# A nova ofensiva de produtos inclui 2 veículos inéditos a serem produzidos na fábrica Anchieta, em São Bernardo do Campo (SP).
#
# Na fábrica da Volkswagen em São José dos Pinhais (PR) será produzida uma pick-up inédita. A Volkswagen confirma que a pick-up Amarok continuará sendo produzida na fábrica de Pacheco, na Argentina.
#
# A unidade da marca em Taubaté (SP) fabricará um automóvel inédito, 100% desenvolvido no Brasil.
#
# A fábrica de motores da Volkswagen do Brasil, em São Carlos (SP), vai produzir um novo motor ainda mais inovador e eficiente para veículos híbridos.
#
# ","A General Motors (GM) anunciou nesta quarta-feira (24) um investimento de R$ 7 bilhões no Brasil até 2028. Segundo a montadora, os investimentos começam a partir deste ano.
# No Brasil, a GM possui cinco fábricas, sendo três delas no Estado de SP -- nas cidades de São José dos Campos, São Caetano do Sul e Mogi das Cruzes --, uma no Rio Grande do Sul, em Gravataí, e outra em Santa Catarina, na cidade de Joinville."]]
# ...

# %%
import pandas as pd 
  
df = pd.read_parquet('mongodb_monitor_de_investimento/mongo_monitor.parquet') 
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>dt_anuncio</th>
#       <th>cnpj_nao_existe</th>
#       <th>cnpj_basico</th>
#       <th>nome_empresa</th>
#       <th>uf</th>
#       <th>setor_investimento</th>
#       <th>setor_empresa</th>
#       <th>objetivo</th>
#       <th>desc</th>
#       <th>...</th>
#       <th>valor</th>
#       <th>unidade_valor</th>
#       <th>fonte</th>
#       <th>origem_recurso</th>
#       <th>nome_responsavel</th>
#       <th>dia_hora_preenchimento</th>
#       <th>historico</th>
#       <th>municipios</th>
#       <th>ano_conclusao</th>
#       <th>ano_inicio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>66b0cc3f42c28f04a512b4df</td>
#       <td>2023-10-03</td>
#       <td>False</td>
#       <td>['33000167']</td>
#       <td>[PETROLEO BRASILEIRO S A PETROBRAS]</td>
#       <td>[Rio Grande do Norte]</td>
#       <td>[Extração de petróleo e gás natural]</td>
#       <td>['0600001']</td>
#       <td>Construção/Implantação</td>
#       <td>O diretor de Exploração e Produção da Petrobra...</td>
#       <td>...</td>
#       <td>300.0</td>
#       <td>Milhões</td>
#       <td>[{'portal': 'BPMoney', 'titulo': 'Petrobras (P...</td>
#       <td>Misto</td>
#       <td>conceicao</td>
#       <td>2024-08-05T12:58:06.256887</td>
#       <td>[{'setor_investimento': ['Extração de petróleo...</td>
#       <td>nan</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td
td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 22 columns</p>
# </div>

# %%
sparkframe = spark.createDataFrame(await process_and_save())
sparkframe
# Out:
# Out[57]: DataFrame[_id: string, dt_anuncio: string, cnpj_nao_existe: boolean, cnpj_basico: string, nome_empresa: array<string>, uf: array<string>, setor_investimento: array<string>, setor_empresa: string, objetivo: string, desc: string, novo_pac: boolean, moeda: string, valor: double, unidade_valor: string, fonte: array<map<string,string>>, origem_recurso: string, nome_responsavel: string, dia_hora_preenchimento: string, historico: string, municipios: string, ano_conclusao: string, ano_inicio: string]

# %%
sparkframe.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>dt_anuncio</th><th>cnpj_nao_existe</th><th>cnpj_basico</th><th>nome_empresa</th><th>uf</th><th>setor_investimento</th><th>setor_empresa</th><th>objetivo</th><th>desc</th><th>novo_pac</th><th>moeda</th><th>valor</th><th>unidade_valor</th><th>fonte</th><th>origem_recurso</th><th>nome_responsavel</th><th>dia_hora_preenchimento</th><th>historico</th><th>municipios</th><th>ano_conclusao</th><th>ano_inicio</th></tr></thead><tbody><tr><td>66b0cc3f42c28f04a512b4df</td><td>2023-10-03</td><td>false</td><td>['33000167']</td><td>List(PETROLEO BRASILEIRO S A PETROBRAS)</td><td>List(Rio Grande do Norte)</td><td>List(Extração de petróleo e gás natural)</td><td>['0600001']</td><td>Construção/Implantação</td><td>O diretor de Exploração e Produção da Petrobras (PETR3; PETR4), Joelson Falcão Mendes, afirmou nesta segunda-feira (2), que a companhia deverá investir cerca de US$ 300 milhões na perfuração de dois poços exploratórios de petróleo e gás em águas profundas da Bacia Potiguar, cujas licenças ambientais foram emitidas pelo Ibama.
# Nesse sentido, a licença do Ibama representa a primeira desde 2013 concedida para perfuração na Margem Equatorial brasileira, uma extensa área que vai do Rio Grande do Norte ao Amapá, considerada uma nova fronteira exploratória de petróleo e gás.</td><td>false</td><td>R$ - Brazilian real</td><td>300.0</td><td>Milhões</td><td>List(Map(titulo -> Petrobras (PETR3) prevê investir cerca de US$ 300 mi na Bacia Potiguar, portal -> BPMoney, url -> https://bpmoney.com.br/mercado/petrobras-petr3-preve-investir-cerca-de-us-300-mi-na-bacia-potiguar/))</td><td>Misto</td><td>conceicao</td><td>2024-08-05T12:58:06.256887</td><td>[{'setor_investimento': ['Extração de petróleo e gás natural'], 'cnpj_nao_existe': False, 'uf': ['Rio Grande do Norte'], 'ano_conclusao': nan, 'cnpj_basico': ['33000167'], 'municipios': nan, 'objetivo': 'Construção/Implantação', 'nome_responsavel': 'conceicao', 'setor_empresa': ['0600001'], 'unidade_valor': 'Milhões', 'valor': 300.0, 'desc': 'O diretor de Exploração e Produção da Petrobras (PETR3; PETR4), Joelson Falcão Mendes, afirmou nesta segunda-feira (2), que a companhia deverá investir cerca de US$ 300 milhões na perfuração de dois poços exploratórios de petróleo e gás em águas profundas da Bacia Potiguar, cujas licenças ambientais foram emitidas pelo Ibama.\nNesse sentido, a licença do Ibama representa a primeira desde 2013 concedida para perfuração na Margem Equatorial brasileira, uma extensa área que vai do Rio Grande do Norte ao Amapá, considerada uma nova fronteira exploratória de petróleo e gás.', 'fonte': [{'portal': 'BPMoney', 'titulo': 'Petrobras (PETR3) prevê investir cerca de US$ 300 mi na Bacia Potiguar', 'url': 'https://bpmoney.com.br/mercado/petrobras-petr3-preve-investir-cerca-de-us-300-mi-na-bacia-potiguar/'}], 'origem_recurso': 'Privado', 'novo_pac': False, 'moeda': 'R$ - Brazilian real', 'ano_inicio': nan, 'dt_anuncio': '2023-10-03', 'nome_empresa': ['PETROLEO BRASILEIRO S A PETROBRAS'], 'dia_hora_preenchimento': '2024-08-05T12:56:47.970880'}]</td><td>nan</td><td>NaN</td><td>NaN</td></tr><tr><td>66b234a8cea5529628c432b3</td><td>2023-06-20</td><td>false</td><td>['26699613']</td><td>List(TERMINAL INVESTMENT LIMITED HOLDING BRASIL LTDA.)</td><td>List(São Paulo)</td><td>List(Armazenamento e atividades auxiliares dos transportes)</td><td>['6462000']</td><td>Ampliação/modernização</td><td>A TIL (Terminal Investment Limited), do grupo de navegação MSC, prevê investimento de R$ 7 bilhões em seus terminais portuários no Brasil, pelos próximos cinco anos. O valor poderá mais do que dobrar a depender das oportunidades de expansão, segundo Ammar Kanaan, presidente global da companhia. Ao todo, o grupo teria R$ 17 bilhões reservados a negócios no país.
# Entre os investimentos já aprovados, R$ 4 bilhões se referem ao BTP, terminal de contêineres no Porto de Santos (SP) que a empresa opera em sociedade com a APM Terminals, da Maersk.</td><td>false</td><td>R$ - Brazilian real</td><td>4.0</td><td>Bilhões</td><td>List(Map(titulo -> MSC planeja expandir terminais no Brasil, portal -> Portal de Fusões e Aquisições, url -> https://fusoesaquisicoes.com/hr/msc-planeja-expandir-terminais-no-brasil/))</td><td>Privado</td><td>marcus</td><td>2024-08-06T14:34:59.373608</td><td>NaN</td><td>['Santos']</td><td>NaN</td><td>NaN</td></tr><tr><td>66b23b4ecea5529628c432ba</td><td>2023-06-20</td><td>false</td><td>['26699613']</td><td>List(TERMINAL INVESTMENT LIMITED HOLDING BRASIL LTDA.)</td><td>List(Santa Catarina)</td><td>List(Armazenamento e atividades auxiliares dos transportes)</td><td>['6462000']</td><td>Construção/Implantação</td><td>A TIL (Terminal Investment Limited), do grupo de navegação MSC, prevê investimento de R$ 7 bilhões em seus terminais portuários no Brasil, pelos próximos cinco anos. O valor poderá mais do que dobrar a depender das oportunidades de expansão, segundo Ammar Kanaan, presidente global da companhia. Ao todo, o grupo teria R$ 17 bilhões reservados a negócios no país. Para além dos investimentos em Santos, a TIL planeja alocar cerca de R$ 3 bilhões em seu terminal de contêineres no Porto de Navegantes, terminal privado operado na região de Itajaí (SC). </td><td>false</td><td>R$ - Brazilian real</td><td>3.0</td><td>Bilhões</td><td>List(Map(titulo -> MSC planeja expandir terminais no Brasil, portal -> Portal de Fusões e Aquisições, url -> https://fusoesaquisicoes.com/hr/msc-planeja-expandir-terminais-no-brasil/))</td><td>Privado</td><td>marcus</td><td>2024-08-06T15:03:36.086291</td><td>NaN</td><td>['Itajaí']</td><td>NaN</td><td>NaN</td></tr><tr><td>66b25855cea5529628c432c3</td><td>2023-11-23</td><td>false</td><td>['04312369']</td><td>List(ESTADO DO AMAZONAS)</td><td>List(Amazonas)</td><td>List(Transporte terrestre)</td><td>['8411600']</td><td>Construção/Implantação</td><td>O Governo do Estado, por meio do Programa Asfalta Amazonas, vai investir aproximadamente R$ 14 milhões na recuperação asfáltica do sistema viário de Novo Aripuanã.
# </td><td>false</td><td>R$ - Brazilian real</td><td>14.0</td><td>Milhões</td><td>List(Map(titulo -> Asfalta Amazonas: Governo do Estado vai investir R$ 14 milhões para recuperação viária de Novo Aripuanã, portal -> Governo do Amazonas, url -> https://www.ugpe.am.gov.br/asfalta-amazonas-governo-do-estado-vai-investir-r-14-milhoes-para-recuperacao-viaria-de-novo-aripuana/))</td><td>Público</td><td>marcus</td><td>2024-08-06T17:24:58.167597</td><td>[{'dt_anuncio': '2023-11-23', 'cnpj_nao_existe': True, 'cnpj_basico': nan, 'nome_empresa': nan, 'uf': ['Amazonas'], 'setor_investimento': ['Transporte terrestre'], 'setor_empresa': nan, 'objetivo': 'Construção/Implantação', 'desc': 'O Governo do Estado, por meio do Programa Asfalta Amazonas, vai investir aproximadamente R$ 14 milhões na recuperação asfáltica do sistema viário de Novo Aripuanã. ', 'novo_pac': True, 'moeda': 'R$ - Brazilian real', 'valor': 14.0, 'unidade_valor': 'Milhões', 'fonte': [{'portal': 'Governo do Amazonas', 'titulo': 'Asfalta Amazonas: Governo do Estado vai investir R$ 14 milhões para recuperação viária de Novo Aripuanã', 'url': 'https://www.ugpe.am.gov.br/asfalta-amazonas-governo-do-estado-vai-investir-r-14-milhoes-para-recuperacao-viaria-de-novo-aripuana/'}], 'origem_recurso': 'Público', 'nome_responsavel': 'marcus', 'dia_hora_preenchimento': '2024-08-06T17:07:30.118410', 'municipios': ['Novo Aripuanã']}]</td><td>['Novo Aripuanã']</td><td>NaN</td><td>NaN</td></tr><tr><td>66b25a38cea5529628c432c6</td><td>2023-12-23</td><td>false</td><td>['04312369']</td><td>List(ESTADO DO AMAZONAS)</td><td>List(Amazonas)</td><td>List(Transporte terrestre)</td><td>['8411600'

# %%
#schema = "oni/trello"
#table = "customfields"
# schema + table = "oni/trello__customfields"

schema = 'oni/mongodb_monitor'
table = 'investimento'
upload_file(spark=spark, dbutils=dbutils, df=sparkframe, schema=schema, table=table)
# Out:
# WARNING:root:No input widget named 'adf' is defined
# WARNING:root:No input widget named 'dls' is defined
# WARNING:root:No input widget named 'table' is defined
# WARNING:root:No input widget named 'tables' is defined
# WARNING:root:No input widget named 'file' is defined
# WARNING:root:Cluster Name: fornecedor_dev
# WARNING:root:Parsed env value is 'dev', and type <class 'str'>
# WARNING:root:Execution env: 'dev'
# WARNING:root:Cluster is interactive: 'True'
# WARNING:root:Escrevendo arquivo!
# WARNING:root:Upload de dados bem-sucedido. Dados escritos em [REDACTED]/tmp/dev/lnd/crw/oni/mongodb_monitor__investimento
